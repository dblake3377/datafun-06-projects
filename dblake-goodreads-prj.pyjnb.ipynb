# %% [markdown]
# Module 6 - Project 6 - Data Analytics Projects
#
# Task 3: Exploratory Data Project
#
# Author: Desiree Blake
#
# This project will show knowledge of python skill within a juypter notebook using my own personal GoodReads export.

# %% [markdown]
# Section 1 - Load DB Goodreads Export CSV

# %%
#Import the CSV
import pandas as pd 
goodreads = pd.read_csv('db-goodreads_library_export.csv')

#Setting precision to 2 decimal points and viewing the head of data
pd.set_option('display.precision', 2) 

goodreads.head(5)
# Out:
#      Book Id                                            Title          Author  \
# 0   63844320      Obsidian Feathers (Fire on the Horizon, #1)      N. Cáceres
# 1   63369521  Revive Me, Part Two: The Affair (New Haven, #3)    J.L. Seegars
# 2   57505461          Keeper of My Soul: A Ganton Hills Novel     Aubreé Pynn
# 3   59344312                                           Verity  Colleen Hoover
# 4  152387598                                Only For The Week  Natasha Bishop
#
#         Author l-f         Additional Authors        ISBN    ISBN13  \
# 0      Cáceres, N.                        NaN         NaN       NaN
# 1    Seegars, J.L.                        NaN         NaN       NaN
# 2     Pynn, Aubreé                        NaN         NaN       NaN
# 3  Hoover, Colleen                        NaN  153872474X  9.78e+12
# 4  Bishop, Natasha  Muddled Ink Editorial Co.         NaN       NaN
#
#    My Rating  Average Rating                         Publisher  ...  \
# ...

# %% [markdown]
# Section 2 - Utilizing Statistics
#
# Basic Descriptive Statistics

# %%
goodreads.describe()
# Out:
#         Book Id    ISBN13  My Rating  Average Rating  Number of Pages  \
# count  2.53e+02  6.40e+01     253.00          253.00           198.00
# mean   5.83e+07  9.78e+12       1.09            4.28           308.09
# std    2.28e+07  2.31e+09       1.93            0.44           125.68
# min    1.87e+03  9.78e+12       0.00            0.00             1.00
# 25%    5.26e+07  9.78e+12       0.00            4.04           232.25
# 50%    5.82e+07  9.78e+12       0.00            4.35           309.50
# 75%    6.13e+07  9.78e+12       2.00            4.59           382.25
# max    1.52e+08  9.80e+12       5.00            4.85           880.00
#
#        Year Published  Original Publication Year  My Review  Spoiler  \
# count          252.00                     139.00        0.0      0.0
# mean          2020.31                    2019.13        NaN      NaN
# std              3.38                       4.38        NaN      NaN
# ...

# %%
# Create Series 
df = pd.read_csv('db-goodreads_library_export.csv')
series1 = df['Bookshelves with positions']
series1.describe()
# Out:
# count                          59
# unique                         59
# top       currently-reading (#28)
# freq                            1
# Name: Bookshelves with positions, dtype: object

# %%
df = pd.read_csv('db-goodreads_library_export.csv')
series2 = df['Number of Pages']
series2.describe()
# Out:
# count    198.00
# mean     308.09
# std      125.68
# min        1.00
# 25%      232.25
# 50%      309.50
# 75%      382.25
# max      880.00
# Name: Number of Pages, dtype: float64

# %% [markdown]
# Section 3 - Histogram

# %%
# %matplotlib
histogram = goodreads.hist()
# Out:
# Using matplotlib backend: <object object at 0x000001E6921E1920>
